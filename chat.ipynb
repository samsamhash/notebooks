# %% [markdown]
# # To use this Rag, just run each cell and in the last cell, click the public url to open the chat interface.

# %%
# !git clone https://github.com/samsamhash/Chat
# Out:
# Cloning into 'Chat'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 21 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 9.33 MiB | 8.95 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !pip install -q gradio sentence-transformers faiss-cpu nltk pdfplumber transformers accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 81.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 92.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 92.6 MB/s eta 0:00:00

# %% [markdown]
# Restart Kernel

# %%
# %cd Chat
# Out:
# /content/Chat

# %%
import nltk
nltk.download("punkt")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
#Load the pdf for the rag and to save in the vector database.
import sys
from ingest_client import ingest_document
from pdf_loader import load_pdf_text

import importlib
import ingest_client
import vector_store
import chunker




pdf_path = "/content/Chat/pokemon.pdf"
doc_id = "coco"

text = load_pdf_text(pdf_path)
res = ingest_document(doc_id, text, chunk_size=300, overlap=50)
print(res)
# Out:
# [VectorStore] Loading embedding model sentence-transformers/all-MiniLM-L6-v2 on device cpu
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# {'status': 'ok', 'chunks_added': 71, 'doc_id': 'coco', 'index_info': {'ntotal': 71, 'n_items': 71, 'index_type': 'flat', 'dim': 384, 'index_path': 'faiss_index.faiss', 'meta_path': 'metadata.json'}}

# %%
# !python chat_ui.py
# Out:
# 2026-01-04 19:58:51.736684: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767556731.768152    1378 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767556731.777791    1378 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767556731.800427    1378 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767556731.800458    1378 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767556731.800468    1378 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767556731.800475    1378 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [VectorStore] Loading embedding model sentence-transformers/all-MiniLM-L6-v2 on device cpu
# tokenizer_config.json: 7.30kB [00:00, 32.6MB/s]
# vocab.json: 2.78MB [00:00, 79.5MB/s]
# merges.txt: 1.67MB [00:00, 144MB/s]
# tokenizer.json: 7.03MB [00:00, 191MB/s]
# config.json: 100% 660/660 [00:00<00:00, 7.10MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: 100% 3.09G/3.09G [00:46<00:00, 65.9MB/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 2.59MB/s]
# [VectorStore] Loading embedding model sentence-transformers/all-MiniLM-L6-v2 on device cpu
# /content/Chat/chat_ui.py:294: DeprecationWarning: The default value of 'allow_tags' in gr.Chatbot will be changed from False to True in Gradio 6.0. You will need to explicitly set allow_tags=False if you want to disable tags in your chatbot.
#   chatbot = gr.Chatbot(elem_id="chatbot", label="Chat", type="messages", height=560, allow_tags=False)
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://7bbc8ac9ba745f2dc3.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Keyboard interruption in main thread... closing server.
# Killing tunnel 0.0.0.0:7860 <> https://7bbc8ac9ba745f2dc3.gradio.live
